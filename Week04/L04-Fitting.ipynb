# %% [markdown]
# # Prof's notes on fitting
# (not in the textbook)

# %% [markdown]
# Interpolation is not the same as fitting
# * When your data is noisy, you probably have to use fitting
# * In physics, we often need to fit to: polynomials, exponentials, Gaussians, etc.
# * Most common methods are "least squares" and "linear regression"
#   * Don't code your own, use libary functions
#   * here I will demonstrate least squares fit to polynomial function

# %% [markdown]
# ## Polynomial fitting using numpy

# %% [markdown]
# I will create a mock noisy dataset, then do simple linear and quadratic fits to it.

# %%
import numpy as np

# mock dataset: relation between x and y is linear with noise
x = np.arange(50.)
y = x + 50.0 * np.random.random(50)

# %%
# plot what the mock dataset looks like
from matplotlib.pyplot import plot
plot(x, y, 'o')

# %%
# Now let's try a linear fit
linfit = np.polyfit(x,y,1)
# linfit is array: first element slope, second element y-intercept
# so best-fit line is: y = linfit[0]*x + linfit[1]
linfit
# Out:
# array([ 0.96826403, 25.41976121])

# %%
# Now let's try a quadratic fit
quadfit = np.polyfit(x,y,2)
# quadfit is array: quadratic coefficient, linear coefficient, constant
# so best-fit line is: y = linfit[0]*x^2 + linfit[1]*x + linfit[2]
quadfit
# Out:
# array([-1.16008254e-03,  1.02510807e+00,  2.49650089e+01])

# %%
# along the best-fit line or curve, we can find the y values corresponding to each of our x values
y_linfit = np.polyval(linfit, x)
y_linfit
# Out:
# array([25.41976121, 26.38802524, 27.35628927, 28.32455331, 29.29281734,
#        30.26108137, 31.2293454 , 32.19760943, 33.16587346, 34.13413749,
#        35.10240152, 36.07066555, 37.03892958, 38.00719361, 38.97545764,
#        39.94372167, 40.9119857 , 41.88024973, 42.84851376, 43.81677779,
#        44.78504182, 45.75330585, 46.72156988, 47.68983391, 48.65809794,
#        49.62636197, 50.594626  , 51.56289003, 52.53115406, 53.4994181 ,
#        54.46768213, 55.43594616, 56.40421019, 57.37247422, 58.34073825,
#        59.30900228, 60.27726631, 61.24553034, 62.21379437, 63.1820584 ,
#        64.15032243, 65.11858646, 66.08685049, 67.05511452, 68.02337855,
#        68.99164258, 69.95990661, 70.92817064, 71.89643467, 72.8646987 ])

# %%
y_quadfit = np.polyval(quadfit, x)
y_quadfit
# Out:
# array([24.96500886, 25.98895685, 27.01058468, 28.02989234, 29.04687984,
#        30.06154717, 31.07389434, 32.08392134, 33.09162817, 34.09701485,
#        35.10008135, 36.10082769, 37.09925387, 38.09535988, 39.08914573,
#        40.08061141, 41.06975693, 42.05658228, 43.04108746, 44.02327248,
#        45.00313734, 45.98068203, 46.95590656, 47.92881092, 48.89939511,
#        49.86765914, 50.83360301, 51.79722671, 52.75853024, 53.71751361,
#        54.67417682, 55.62851986, 56.58054273, 57.53024544, 58.47762799,
#        59.42269037, 60.36543258, 61.30585463, 62.24395651, 63.17973823,
#        64.11319979, 65.04434118, 65.9731624 , 66.89966346, 67.82384435,
#        68.74570508, 69.66524565, 70.58246605, 71.49736628, 72.40994635])

# %%
# Now let's visualize the best-fit results
plot(x, y, 'o')
plot(x,y_linfit, y_quadfit)
# Out:
# [<matplotlib.lines.Line2D at 0x7fd4941f1c90>,
#  <matplotlib.lines.Line2D at 0x7fd4941f1cc0>]

# %% [markdown]
# As we would expect (because the mock dataset was ~ linear), the quadratic coefficient is very close to zero, so gives almost the identical result to the linear fit

# %% [markdown]
# * numpy.polynomial has similar functions to fit to: Chebyshev series, Hermite series, Laguerre series, Legendre series, etc.
# * See:
#     https://numpy.org/doc/stable/reference/generated/numpy.polynomial.polynomial.polyfit.html
#     https://numpy.org/doc/stable/reference/generated/numpy.polyfit.html
